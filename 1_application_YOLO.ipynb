# %%
# import librairies
from ultralytics import YOLO
import os
import cv2
# import numpy as np

from IPython.display import Image, display

# from pathlib import Path
# Out:
# /home/aaron/anaconda3/envs/ultral_3/lib/python3.10/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
path_modele = '/home/aaron/Documents/M2/memoire_M2/0_Rendu_M2/best.pt'

# %%
model_annuaires = YOLO(model=path_modele, task='segment')

# %%
path_folder = '/home/aaron/Documents/M2/memoire_M2/B_liste_png/'

# %%
for file in sorted(os.listdir(path_folder)):
    if file.endswith('.png'):
        path_image = os.path.join(path_folder, file)
        result_image = model_annuaires(source=path_image, save_crop=True)
# Out:
# image 1/1 /home/aaron/Documents/M2/memoire_M2/B_liste_png/output001.png: 640x480 1 col_1, 1 col_2, 3 col_3s, 105.9ms
# Speed: 2.7ms preprocess, 105.9ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict2
#
# image 1/1 /home/aaron/Documents/M2/memoire_M2/B_liste_png/output002.png: 640x480 1 col_1, 1 col_2, 1 col_3, 86.9ms
# Speed: 2.9ms preprocess, 86.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict2
#
# image 1/1 /home/aaron/Documents/M2/memoire_M2/B_liste_png/output003.png: 640x480 1 col_1, 1 col_2, 1 col_3, 85.3ms
# Speed: 2.6ms preprocess, 85.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict2
#
# image 1/1 /home/aaron/Documents/M2/memoire_M2/B_liste_png/output004.png: 640x480 1 col_1, 1 col_2, 1 col_3, 105.3ms
# Speed: 2.8ms preprocess, 105.3ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 480)
# ...

# %% [markdown]
# Nous obtenons tous les crops dans le dossier **/runs/segment/predict/crops/**.
#
# "runs" se trouve dans le meme dossier que le modèle "best.pt".
#
# Et "crops" contient 3 dossiers correspondant aux 3 classes de notre modèle. Dans chaque dossier se trouve les crops effectués par le modèle.

# %% [markdown]
# Nous batch-renommons tous le fichiers pour rajouter la classe a la fin de leur nom et nous les rangeons dans un dossier unique.

# %% [markdown]
# **Note** : si le modèle détecte plusieurs col_1 sur l'image `output018.jpg`, il va sauvegarder la première sous le nom `output018.jpg`, puis les suivantes sous les noms `output0182.jpg`, `output0183.jpg`, etc.
